# %% [markdown]
# # Estadísticas descriptivas

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                   'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df.describe()
# Out:
#                  a            b            c
# count  1000.000000  1000.000000  1000.000000
# mean      1.051117     0.011472    -0.953365
# std       1.001981     0.956752     1.000421
# min      -2.163184    -3.240844    -4.961107
# 25%       0.401103    -0.589487    -1.611744
# 50%       1.074985     0.024101    -0.949087
# 75%       1.735473     0.629226    -0.262731
# max       3.939771     3.375214     3.115664

# %%
df.plot.hist(bins=20, stacked=True)

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f26971c45f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2697192ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f26971628d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f269711f470>]], dtype=object)

# %%
df.plot.box()

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200)

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2696b846d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2696ab2940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2696b01358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2696a38080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2696a00588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26969bb908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2696984b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f269693f8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f26969099e8>]], dtype=object)
